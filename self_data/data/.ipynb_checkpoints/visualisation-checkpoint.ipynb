# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
walk = pd.read_csv('./up/up2.csv')
#down = pd.read_csv('down.csv')

# %%
walk
# Out:
#                Timestamp  Milliseconds         X         Y          Z
# 0    2019-04-26 13:21:25             2  0.529648  2.957489   9.184143
# 1    2019-04-26 13:21:25            21  0.206421  3.639832   8.827408
# 2    2019-04-26 13:21:25            41  0.505707  3.704483   8.518555
# 3    2019-04-26 13:21:25            61  0.800186  3.579987   8.681366
# 4    2019-04-26 13:21:25            82  0.842087  3.566818   9.078812
# 5    2019-04-26 13:21:25           101  0.795395  3.319015   9.214081
# 6    2019-04-26 13:21:25           121  0.280640  3.333374   9.006973
# 7    2019-04-26 13:21:25           143 -0.145523  3.517731   8.793900
# 8    2019-04-26 13:21:25           161  0.031647  3.483017   8.719681
# 9    2019-04-26 13:21:25           182  0.010101  3.486603   9.130280
# 10   2019-04-26 13:21:25           201 -0.018631  3.560821   9.436737
# 11   2019-04-26 13:21:25           222  0.055588  3.664978   9.297882
# ...

# %%
plt.figure(figsize=(20,10))

# %%
sns.lineplot(y=walk['Y'],x = np.arange(len(walk)))
plt.show()

# %%
sns.lineplot(y=walk['Z'],x = np.arange(len(walk)))
plt.show()
