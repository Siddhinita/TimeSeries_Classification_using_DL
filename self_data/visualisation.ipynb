# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sup

# %%
walk1 = pd.read_csv('./up/u2.csv')
walk2 = pd.read_csv('./walk/w1.csv')
walk3 = pd.read_csv('./down/d2.csv')
#print(len(walk))
#walk = walk[::2]
print(len(walk))
#down = pd.read_csv('down.csv')
# Out:
# 1103

# %%
plt.figure(figsize=(20,10))

# %%
l = 100

# %%
plt.title('Climbing Up')
sns.lineplot(y=walk1.ix[500:500+l,'Y'],x = np.arange(len(walk1.ix[500:500+l,'Y'])))
plt.show()
plt.title('Climbing Down')
sns.lineplot(y=walk3.ix[:l,'Y'],x = np.arange(len(walk3.ix[:l,'Y'])))
plt.show()
plt.title("Walking")
sns.lineplot(y=walk2.ix[:l,'Y'],x = np.arange(len(walk2.ix[:l,'Y'])))
plt.show()

# %%
walk.ix[4050:4700,:].to_csv('./up/c.csv')
# Out:
# /home/sid/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.lineplot(y=walk['Z'],x = np.arange(len(walk)))
plt.show()
